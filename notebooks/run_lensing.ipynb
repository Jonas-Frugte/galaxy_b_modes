# %%
from b_modes_modules.calculate_lensing import lens_catalogue
from b_modes_modules.lens_spec import LensSpec
from b_modes_modules.cosmology_spec import CosmologySpec
from b_modes_modules.filepaths import FilePaths

lens_spec = LensSpec(lmax_cut=512)
for lc in [1,]:
    filepaths = FilePaths(CAT_NAME=f"real_cat_{lc}")

    lens_catalogue(lens_spec=lens_spec, filepaths=filepaths, alms_from_stored=True, batch_size=int(4e7))
# Out:
# batch 0:38171413 / 38171413
# 100%|██████████| 68/68 [08:04<00:00,  7.12s/it]
#   done (38171413 galaxies, peak RAM 20.5 GB)
# wrote 38171413 galaxies to /Users/Frugt001/Desktop/flamingo_data/real_cat_1/shells_lensed_4096.hdf5
